# %% [markdown]
# ## 2018 Stat Scraping

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Create a dictionary of NFL teams w/ pertinent info.

# %%
NFL = {
    "Cardinals":{'team':'ArizonaAri', 'team_2':'Arizona Cardinals','team_3':'Arizona','bye':9,
                'Dates':['2018090901',
 '2018091601',
 '2018092301',
 '2018093002',
 '2018100701',
 '2018101401',
 '2018101801',
 '2018102802',
 '0',
 '2018111101',
 '2018111801',
 '2018112501',
 '2018120201',
 '2018120901',
 '2018121601',
 '2018122301',
 '2018123001'],
                'Superbowl_Win':0, 'Playoff_app_5_yrs':3, 'Draft_Pos':10, 'Perc_Pro_Bowl':3/53},
    
    "Falcons":{'team':'AtlantaAtl','team_2':'Atlanta Flacons','team_3':'Atlanta', 'bye':8,
               'Dates':['2018090601',
 '2018091602',
 '2018092302',
 '2018093003',
 '2018100702',
 '2018101402',
 '2018102201',
 '0',
 '2018110401',
 '2018111102',
 '2018111802',
 '2018112201',
 '2018120202',
 '2018120902',
 '2018121601',
 '2018122302',
 '2018123002'],
               'Superbowl_Win':0, 'Playoff_app_5_yrs': 5, 'Draft_Pos':26, 'Perc_Pro_Bowl': 6/53},
    
    "Panthers":{'team':'CarolinaCar','team_2':'Carolina Panthers','team_3':'Carolina', 'bye':4,
    'Dates':['2018090903',
 '2018091602',
 '2018092305',
 '0',
 '2018100705',
 '2018101405',
 '2018102103',
 '2018102803',
 '2018110404',
 '2018110801',
 '2018111804',
 '2018112504',
 '2018120204',
 '2018120905',
 '2018121701',
 '2018122302',
 '2018123005'],
    'Superbowl_Win':0, 'Playoff_app_5_yrs': 7, 'Draft_Pos':24, 'Perc_Pro_Bowl': 5/53},
    
    "Bears":{'team':'ChicagoChi','team_2':'Chicago Bears','team_3':'Chicago', 'bye':5,
            'Dates':['2018090904',
 '2018091701',
 '2018092301',
 '2018093006',
 '0',
 '2018101406',
 '2018102104',
 '2018102804',
 '2018110403',
 '2018111104',
 '2018111805',
 '2018112202',
 '2018120205',
 '2018120906',
 '2018121604',
 '2018122305',
 '2018123006',
 '2019010602'],
            'Superbowl_Win': 0, 'Playoff_app_5_yrs':0, 'Draft_Pos':8, 'Perc_Pro_Bowl':2/53},
    
    "Cowboys":{'team':'DallasDal','team_2':'Dallas Cowboys','team_3':'Dallas', 'bye':8,
              'Dates':['2018090903',
 '2018091605',
 '2018092306',
 '2018093008',
 '2018100707',
 '2018101409',
 '2018102107',
 '0',
 '2018110501',
 '2018111106',
 '2018111802',
 '2018112203',
 '2018112901',
 '2018120908',
 '2018121606',
 '2018122307',
 '2018123008',
 '2019010502',
 '2019011202'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':3, 'Draft_Pos':19, 'Perc_Pro_Bowl':7/53},
    
    "Lions":{'team':'DetroitDet','team_2':'Detroit Lions','team_3':'Detroit', 'bye':6,
              'Dates':['2018091001',
 '2018091607',
 '2018092307',
 '2018093008',
 '2018100709',
 '0',
 '2018102108',
 '2018102808',
 '2018110407',
 '2018111104',
 '2018111804',
 '2018112202',
 '2018120208',
 '2018120901',
 '2018121603',
 '2018122308',
 '2018123010'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':2, 'Draft_Pos':20, 'Perc_Pro_Bowl':1/53},
    
    "Packers":{'team':'Green BayGB', 'team_2':'Green Bay Packers', 'team_3':'Green Bay','bye': 7,
               'Dates':['2018090904',
 '2018091608',
 '2018092308',
 '2018093005',
 '2018100709',
 '2018101501',
 '0',
 '2018102809',
 '2018110408',
 '2018111107',
 '2018111501',
 '2018112507',
 '2018120201',
 '2018120902',
 '2018121604',
 '2018122309',
 '2018123010'], 
               'Superbowl_Win': 0, 'Playoff_app_5_yrs':8, 'Draft_Pos': 18, 'Perc_Pro_Bowl': 4/53},
    
    "Rams":{'team':'LA RamsLA','team_2':'LA Rams','team_3':'LA', 'bye':12,
              'Dates':['2018091002',
 '2018091601',
 '2018092313',
 '2018092701',
 '2018100712',
 '2018101410',
 '2018102111',
 '2018102809',
 '2018110410',
 '2018111110',
 '2018111901',
 '0',
 '2018120208',
 '2018120906',
 '2018121608',
 '2018122301',
 '2018123014',
 '2019011202',
 '2019012001',
 '2019020301'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':1, 'Draft_Pos':89, 'Perc_Pro_Bowl':3/53},
    
    "Vikings":{'team':'MinnesotaMin','team_2':'Minnesota Vikings','team_3':'Minnesota', 'bye':10,
              'Dates':['2018090912',
 '2018091608',
 '2018092304',
 '2018092701',
 '2018100713',
 '2018101401',
 '2018102112',
 '2018102812',
 '2018110407',
 '0',
 '2018111805',
 '2018112507',
 '2018120212',
 '2018121001',
 '2018121609',
 '2018122308',
 '2018123006'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':3, 'Draft_Pos':30, 'Perc_Pro_Bowl':6/53},
    
    "Saints":{'team':'New OrleansNO','team_2':'New Orleans Saints','team_3':'New Orleans', 'bye':6,
              'Dates':['2018090913',
 '2018091604',
 '2018092302',
 '2018093013',
 '2018100803',
 '0',
 '2018102101',
 '2018102812',
 '2018110410',
 '2018111105',
 '2018111810',
 '2018112201',
 '2018112901',
 '2018120912',
 '2018121701',
 '2018122314',
 '2018123005',
 '2019011302',
 '2019012001'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':4, 'Draft_Pos':14, 'Perc_Pro_Bowl':1/53},
    
    "Giants":{'team':'NY GiantsNYG','team_2':'New York Giants','team_3':'New York', 'bye':9,
              'Dates':['2018090909',
 '2018091605',
 '2018092309',
 '2018093013',
 '2018100705',
 '2018101101',
 '2018102201',
 '2018102813',
 '0',
 '2018111201',
 '2018111811',
 '2018112510',
 '2018120205',
 '2018120913',
 '2018121611',
 '2018122311',
 '2018123008'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':1, 'Draft_Pos':2, 'Perc_Pro_Bowl':4/53},
    
    "Eagles":{'team':'PhiladelphiaPhi','team_2':'Philadelphia Eagles','team_3':'Philadelphia', 'bye':9,
              'Dates':['2018090601',
 '2018091614',
 '2018092310',
 '2018093014',
 '2018100713',
 '2018101101',
 '2018102103',
 '2018102811',
 '0',
 '2018111106',
 '2018111810',
 '2018112510',
 '2018120301',
 '2018120908',
 '2018121608',
 '2018122310',
 '2018123016',
 '2019010602',
 '2019011302'],
              'Superbowl_Win':1, 'Playoff_app_5_yrs':4, 'Draft_Pos':49, 'Perc_Pro_Bowl':4/53},
    
    "49ers":{'team':'San FranciscoSF','team_2':'San Francisco 49ers', 'team_3':'San Francisco', 'bye':11, 
            'Dates':['2018090912',
 '2018091607',
 '2018092312',
 '2018093011',
 '2018100701',
 '2018101501',
 '2018102111',
 '2018102802',
 '2018110101',
 '2018111201',
 '0',
 '2018112511',
 '2018120214',
 '2018120909',
 '2018121612',
 '2018122305',
 '2018123014'], 'Superbowl_Win': 0, 'Playoff_app_5_yrs': 3, 'Draft_Pos': 9, 'Perc_Pro_Bowl': 0/53},
    
    "Seahawks":{'team':'SeattleSea','team_2':'Seattle Seahawks','team_3':'Seattle', 'bye':7,
              'Dates':['2018090907',
 '2018091701',
 '2018092306',
 '2018093002',
 '2018100712',
 '2018101413',
 '0',
 '2018102808',
 '2018110409',
 '2018111110',
 '2018111501',
 '2018112504',
 '2018120214',
 '2018121001',
 '2018121612',
 '2018122313',
 '2018123001',
 '2019010502'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':10, 'Draft_Pos':27, 'Perc_Pro_Bowl':7/53},
    
    "Buccaneers":{'team':'Tampa BayTB','team_2':'Tampa Bay Buccaneers','team_3':'Tampa Bay', 'bye':5,
              'Dates':['2018090913',
 '2018091614',
 '2018092401',
 '2018093006',
 '0',
 '2018101402',
 '2018102106',
 '2018102805',
 '2018110404',
 '2018111112',
 '2018111811',
 '2018112511',
 '2018120204',
 '2018120912',
 '2018121602',
 '2018122307',
 '2018123002'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':0, 'Draft_Pos':12, 'Perc_Pro_Bowl':2/53},
    
    "Redskins":{'team':'WashingtonWas', 'team_2':'Washington Redskins','team_3':'Washington','bye':4, 
                'Dates':['2018090901',
 '2018091610',
 '2018092308',
 '0',
 '2018100803',
 '2018101405',
 '2018102107',
 '2018102813',
 '2018110401',
 '2018111112',
 '2018111807',
 '2018112203',
 '2018120301',
 '2018120913',
 '2018121607',
 '2018122315',
 '2018123016'], 
                'Superbowl_Win': 0, 'Playoff_app_5_yrs': 1, 'Draft_Pos': 13, 'Perc_Pro_Bowl': 5/53 },
    
    "Ravens":{'team':'BaltimoreBal', 'team_2':'Baltimore Ravens', 'team_3': 'Baltimore', 'bye': 10, 
             'Dates':['2018090902',
 '2018091301',
 '2018092303',
 '2018093004',
 '2018100703',
 '2018101403',
 '2018102101',
 '2018102803',
 '2018110402',
 '0',
 '2018111803',
 '2018112502',
 '2018120202',
 '2018120903',
 '2018121602',
 '2018122303',
 '2018123003',
 '2019010601'], 
              'Superbowl_Win': 0, 'Playoff_app_5_yrs':2, 'Draft_Pos':25,'Perc_Pro_Bowl': 7/53},
    
    "Bills":{'team':'BuffaloBuf','team_2':'Buffalo Bills','team_3':'Buffalo', 'bye':11,
            'Dates':['2018090902',
 '2018091603',
 '2018092304',
 '2018093005',
 '2018100704',
 '2018101404',
 '2018102102',
 '2018102901',
 '2018110403',
 '2018111103',
 '0',
 '2018112503',
 '2018120203',
 '2018120904',
 '2018121603',
 '2018122304',
 '2018123004'], 
             'Superbowl_Win': 0, 'Playoff_app_5_yrs':1, 'Draft_Pos':7, 'Perc_Pro_Bowl': 6/53},
    
     "Bengals":{'team':'CincinnatiCin','team_2':'Cincinnati Bengals','team_3':'Cincinnati', 'bye':9,
              'Dates':['2018090905',
 '2018091301',
 '2018092305',
 '2018093003',
 '2018100706',
 '2018101407',
 '2018102105',
 '2018102805',
 '0',
 '2018111105',
 '2018111803',
 '2018112505',
 '2018120206',
 '2018120907',
 '2018121605',
 '2018122306',
 '2018123007'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':3, 'Draft_Pos':21, 'Perc_Pro_Bowl':5/53},
    
    "Browns":{'team':'ClevelandCle','team_2':'Cleveland Browns','team_3':'Cleveland', 'bye':11,
              'Dates':['2018090906',
 '2018091604',
 '2018092001',
 '2018093007',
 '2018100703',
 '2018101408',
 '2018102106',
 '2018102806',
 '2018110405',
 '2018111102',
 '0',
 '2018112505',
 '2018120207',
 '2018120905',
 '2018121501',
 '2018122306',
 '2018123003'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':0, 'Draft_Pos':1, 'Perc_Pro_Bowl':1/53},
    
    "Broncos":{'team':'DenverDen','team_2':'Denver Broncos','team_3':'Denver', 'bye':10,
              'Dates':['2018090907',
 '2018091606',
 '2018092303',
 '2018100101',
 '2018100708',
 '2018101410',
 '2018101801',
 '2018102807',
 '2018110406',
 '0',
 '2018111806',
 '2018112506',
 '2018120206',
 '2018120909',
 '2018121501',
 '2018122401',
 '2018123009'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':7, 'Draft_Pos':5, 'Perc_Pro_Bowl':6/53},
    
    "Texans":{'team':'HoustonHou','team_2':'Houston Texans','team_3':'Houston', 'bye':10,
              'Dates':['2018090908',
 '2018091609',
 '2018092309',
 '2018093009',
 '2018100707',
 '2018101404',
 '2018102109',
 '2018102501',
 '2018110406',
 '0',
 '2018111807',
 '2018112601',
 '2018120207',
 '2018120910',
 '2018121502',
 '2018122310',
 '2018123011',
 '2019010501'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':3, 'Draft_Pos':68, 'Perc_Pro_Bowl':1/53},
    
    "Colts":{'team':'IndianapolisInd','team_2':'Indianapolis Colts','team_3':'Indianapolis', 'bye':9,
              'Dates':['2018090905',
 '2018091610',
 '2018092310',
 '2018093009',
 '2018100401',
 '2018101411',
 '2018102102',
 '2018102810',
 '0',
 '2018111108',
 '2018111808',
 '2018112508',
 '2018120209',
 '2018120910',
 '2018121606',
 '2018122311',
 '2018123012',
 '2019010501',
 '2019011201'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':5, 'Draft_Pos':6, 'Perc_Pro_Bowl':2/53},
    
    "Jaguars":{'team':'JacksonvilleJax','team_2':'Jacksonville Jaguars','team_3':'Jacksonville', 'bye':9,
              'Dates':['2018090909',
 '2018091611',
 '2018092311',
 '2018093010',
 '2018100710',
 '2018101409',
 '2018102109',
 '2018102811',
 '0',
 '2018111108',
 '2018111809',
 '2018112503',
 '2018120209',
 '2018120601',
 '2018121607',
 '2018122312',
 '2018123011'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':3, 'Draft_Pos':29, 'Perc_Pro_Bowl':0/53},
    
    "Chiefs":{'team':'Kansas CityKC','team_2':'Kansas City Chiefs','team_3':'Kansas City', 'bye':12,
              'Dates':['2018090910',
 '2018091612',
 '2018092312',
 '2018100101',
 '2018100710',
 '2018101412',
 '2018102105',
 '2018102807',
 '2018110405',
 '2018111101',
 '2018111901',
 '0',
 '2018120210',
 '2018120903',
 '2018121301',
 '2018122313',
 '2018123013',
 '2019011201',
 '2019012002'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':5, 'Draft_Pos':46, 'Perc_Pro_Bowl':7/53},
    
    "Raiders":{'team':'OaklandOak','team_2':'Oakland Raiders','team_3':'Oakland', 'bye':7,
              'Dates':['2018091002',
 '2018091606',
 '2018092314',
 '2018093007',
 '2018100711',
 '2018101413',
 '0',
 '2018102810',
 '2018110101',
 '2018111109',
 '2018111801',
 '2018112502',
 '2018120210',
 '2018120914',
 '2018121605',
 '2018122401',
 '2018123013'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':1, 'Draft_Pos':15, 'Perc_Pro_Bowl':7/53},
    
    "Chargers":{'team':'LA ChargersLAC','team_2':'Los Angeles Chargers','team_3':'Los Angeles', 'bye':8,
              'Dates':['2018090910',
 '2018091603',
 '2018092313',
 '2018093011',
 '2018100711',
 '2018101408',
 '2018102110',
 '0',
 '2018110409',
 '2018111109',
 '2018111806',
 '2018112501',
 '2018120211',
 '2018120907',
 '2018121301',
 '2018122303',
 '2018123009', 
 '2019010601',
 '2019011301'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':2, 'Draft_Pos':17, 'Perc_Pro_Bowl':3/53},
    
    "Dolphins":{'team':'MiamiMia','team_2':'Miami Dolphins','team_3':'Miami', 'bye':11,
               'Dates':['2018090911',
 '2018091613',
 '2018092314',
 '2018093012',
 '2018100706',
 '2018101406',
 '2018102108',
 '2018102501',
 '2018110411',
 '2018111107',
 '0',
 '2018112508',
 '2018120203',
 '2018120911',
 '2018121609',
 '2018122312',
 '2018123004'],
               'Superbowl_Win':0, 'Playoff_app_5_yrs': 1, 'Draft_Pos':11, 'Perc_Pro_Bowl': 4/53},
    
    "Patriots":{'team':'New EnglandNE','team_2':'New England Patriots','team_3':'New England', 'bye':11,
               'Dates':['2018090908',
 '2018091611',
 '2018092307',
 '2018093012',
 '2018100401',
 '2018101412',
 '2018102104',
 '2018102901',
 '2018110408',
 '2018111111',
 '0',
 '2018112509',
 '2018120212',
 '2018120911',
 '2018121610',
 '2018122304',
 '2018123015',
 '2019011301',
 '2019012002',
 '2019020301'],
               'Superbowl_Win':0, 'Playoff_app_5_yrs': 13, 'Draft_Pos':23, 'Perc_Pro_Bowl': 4/53},
    
    "Jets":{'team':'NY JetsNYJ','team_2':'New York Jets','team_3':'New York', 'bye':11,
              'Dates':['2018091001',
 '2018091613',
 '2018092001',
 '2018093010',
 '2018100708',
 '2018101411',
 '2018102112',
 '2018102804',
 '2018110411',
 '2018111103',
 '0',
 '2018112509',
 '2018120213',
 '2018120904',
 '2018121502',
 '2018122309',
 '2018123015'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':0, 'Draft_Pos':3, 'Perc_Pro_Bowl':1/53},
    
    "Steelers":{'team':'PittsburghPit','team_2':'Pitsburgh Steelers','team_3':'Pittsburgh', 'bye':7,
              'Dates':['2018090906',
 '2018091612',
 '2018092401',
 '2018093004',
 '2018100702',
 '2018101407',
 '0',
 '2018102806',
 '2018110402',
 '2018110801',
 '2018111809',
 '2018112506',
 '2018120211',
 '2018120914',
 '2018121610',
 '2018122314',
 '2018123007'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':7, 'Draft_Pos':28, 'Perc_Pro_Bowl':6/53},
    
    "Titans":{'team':'TennesseeTen','team_2':'Tennessee Titans','team_3':'Tennessee', 'bye':8,
              'Dates':['2018090911',
 '2018091609',
 '2018092311',
 '2018093014',
 '2018100704',
 '2018101403',
 '2018102110',
 '0',
 '2018110501',
 '2018111111',
 '2018111808',
 '2018112601',
 '2018120213',
 '2018120601',
 '2018121611',
 '2018122315',
 '2018123012'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':2, 'Draft_Pos':22, 'Perc_Pro_Bowl':5/53},

}

# %% [markdown]
# 2. Create dataframe

# %%
def Team_Stats(team_name):
    
    '''input: team name 
       output: dataframe w/ weekly statistics from all 32 NFL teams'''

    #create df w/ all columns
    df = pd.DataFrame(columns=[       'Team_Name',
                                      'Pts_Scored',
                                      'Pts_Al',
                                      'Win',
                                      'TDs',
                                      'First_Sc',
                                      'Second_Sc',
                                      'Third_Sc',
                                      'Fourth_Sc',
                                      'First_Al',
                                      'Second_Al',
                                      'Third_Al',
                                      'Fourth_Al',

                                      'Off_Plys',
                                      'Rush_Plys',
                                      'Pass_Plys',
                                      'Fumbles',
                                      'Perc_Rush',
                                      'Perc_Pass',

                                      'Yds_Ply',
                                      'Yds_Rush',
                                      'Yds_Pass',
                                      'Total_Yds_Gm',
                                      'Total_Rush_Yds_Gm',
                                      'Total_Pass_Yds_Gm',
                                    
                                      'Yds_Ply_Al',
                                      'Yds_Rush_Al',
                                      'Yds_Pass_Al',
                                      'Total_Yds_Gm_Al',
                                      'Total_Rush_Yds_Gm_Al',
                                      'Total_Pass_Yds_Gm_Al',
                                      'Off_Plys_Al',
                                      'Rush_Plys_Al',
                                      'Pass_Plys_Al',
                                    
                                      'Completion_Rate',
                                      'Pass_Att',
                                      'Pass_TDs',
                                      'INTs',
                                      'Sacks_Taken',
                                    
                                      'Num_Rushers',
                                      'Rush_TDs',
                                      'Rush_Att',
                                      
                                      'Pass_1Ds_Gm',
                                      'Rush_1Ds_Gm',
                                      'First_Ds_Gm',
                                      'Third_Conv_Perc',
                                      'Fourth_Conv_Perc',
                                      
                                      'Sacks_Gm',
                                      'INT_Gm',
                                      'Fumbles_Caused',
                                      'TO_Gm',

                                      'FG_Att',
                                      'FG_Perc_Comp',

                                      'PAT_Att',
                                      'PAT_Perc_Comp',

                                      'Punts',
                                      'Avg_Punt_Yds_Gm',
                                      'Avg_Punt_Ret_Yds_Gm',
                                      'Avg_Punt_Ret_Yds_Opp_Gm',
                                      'Total_Punt_Ret_Yds_Gm',
                                      'Total_Punt_Ret_Yds_Opp_Gm',
                                      'Punt_Ret_TD',
                                      'Punt_Ret_TD_Opp',
                                    
                                      'Avg_Kick_Ret_Yds_Gm',
                                      'Avg_Kick_Ret_Yds_Opp_Gm',
                                      'Kick_Ret_TD_Opp',
                                      'Kick_Ret_TD',

                                      'Penalties',
                                      'Penalty_Gm',
                                      'Penalty_Yds_Gm',

                                      'Playoff_app_5_yrs',
                                      'Superbowl_Win',
                                      'Draft_Pos',
                                      'Week_Of_Szn',
                                     'Perc_Pro_Bowl'])

    #for loop which will loop thru each week in list of dates for a single nfl team
    for week,date in enumerate(NFL[team_name]['Dates']):
        Week = int(week) + 1
        if date == '0':
            df.fillna(np.nan)
        else:
            bye = NFL[team_name]['bye']
            if week < bye:
                num = week
            else: 
                num = week - 1
            team = NFL[team_name]['team']
            team_2 = NFL[team_name]['team_2']
            team_3 = NFL[team_name]['team_3']
            week = ('Week_' + str(Week))
            #looping thru dates 
            stats = pd.read_html('https://www.footballdb.com/games/boxscore.html?gid=' + date)
            #the website has different order based on home/away, fixed below
            if stats[3].columns[2] == team:
                #home
                x = 2 
                y = 1
                a = 5
                b = 4
                c = 7
                d = 6
                e = 21
                f = 20
                g = 17
                h = 16
                i = 15
                j = 14
                k = 13
                l = 12
                m = 11
                n = 10
            else:
                #away
                a = 4
                b = 5
                c = 6
                d = 7
                x = 1
                y = 2
                e = 20
                f = 21
                g = 16
                h = 17
                i = 14
                j = 15
                k = 12
                l = 13
                m = 10
                n = 11
            
            opp = stats[3].columns[y]
            
            df.loc[week, 'Team_Name'] = team_name
            
            df.loc[week, 'Opp_Name'] = stats[3].columns[y]

            ##SCORING
            # Weekly
            if len(stats[0].columns) == 7:
                Pts_Scored = stats[0][6][x]
            else: 
                Pts_Scored = stats[0][5][x]
            df.loc[week, 'Pts_Scored'] = int(Pts_Scored)

            if len(stats[0].columns) == 7:
                Pts_Al = stats[0][6][y]
            else:
                Pts_Al = stats[0][5][y]
            df.loc[week, 'Pts_Al'] = int(Pts_Al)

            if df.Pts_Al[num] < df.Pts_Scored[num]:
                Win = 1
            else:
                Win = 0
            df.loc[week, 'Win'] = float(Win)

            TDs = stats[a]['TD'].sum() + stats[c]['TD'].sum()
            df.loc[week, 'TDs'] = float(TDs)

            First_Sc = stats[0][1][x]
            df.loc[week, 'First_Sc' ] = float(First_Sc)

            Second_Sc = stats[0][2][x]
            df.loc[week, 'Second_Sc' ] = float(Second_Sc)

            Third_Sc = stats[0][3][x]
            df.loc[week, 'Third_Sc'] = float(Third_Sc)

            Fourth_Sc = stats[0][4][x]
            df.loc[week, 'Fourth_Sc'] = float(Fourth_Sc)

            First_Al = stats[0][1][y]
            df.loc[week, 'First_Al'] = float(First_Al)

            Second_Al = stats[0][2][y]
            df.loc[week, 'Second_Al'] = float(Second_Al)

            Third_Al = stats[0][3][y]
            df.loc[week, 'Third_Al'] = float(Third_Al)

            Fourth_Al = stats[0][4][y]
            df.loc[week, 'Fourth_Al'] = float(Fourth_Al)

            ##OFFENSE 
            #weekly 
            Off_Plys = stats[3][team][10]
            df.loc[week, 'Off_Plys'] = int(Off_Plys)

            Rush_Plys = stats[2][team][6]
            df.loc[week, 'Rush_Plys'] = int(Rush_Plys)

            Pass_Plys = stats[2][team][9].split('-')[0]
            df.loc[week, 'Pass_Plys'] = int(Pass_Plys)

            Fumbles = stats[3][team][6][2]
            df.loc[week, 'Fumbles'] = float(Fumbles)

            ## OFFENSIVE YARDAGE 
            #weekly
            Yds_Ply = stats[3][team][11]
            df.loc[week, 'Yds_Ply'] = float(Yds_Ply)

            Yds_Rush = stats[2][team][7]
            df.loc[week, 'Yds_Rush'] = float(Yds_Rush)

            Yds_Pass = stats[2][team][12]
            df.loc[week, 'Yds_Pass'] = float(Yds_Pass)

            Total_Yds_Gm = stats[2][team][4]
            df.loc[week, 'Total_Yds_Gm'] = float(Total_Yds_Gm)

            Total_Rush_Yds_Gm = stats[2][team][5]
            df.loc[week, 'Total_Rush_Yds_Gm'] = float(Total_Rush_Yds_Gm)

            Total_Pass_Yds_Gm = stats[2][team][8]
            df.loc[week, 'Total_Pass_Yds_Gm'] = float(Total_Pass_Yds_Gm)
            
            ## YARDS ALLOWED 
             #weekly
            Yds_Ply_Al = stats[3][opp][11]
            df.loc[week, 'Yds_Ply_Al'] = float(Yds_Ply)

            Yds_Rush_Al = stats[2][opp][7]
            df.loc[week, 'Yds_Rush_Al'] = float(Yds_Rush_Al)

            Yds_Pass_Al = stats[2][opp][12]
            df.loc[week, 'Yds_Pass_Al'] = float(Yds_Pass_Al)

            Total_Yds_Gm_Al = stats[2][opp][4]
            df.loc[week, 'Total_Yds_Gm_Al'] = float(Total_Yds_Gm_Al)

            Total_Rush_Yds_Gm_Al = stats[2][opp][5]
            df.loc[week, 'Total_Rush_Yds_Gm_Al'] = float(Total_Rush_Yds_Gm_Al)

            Total_Pass_Yds_Gm_Al = stats[2][opp][8]
            df.loc[week, 'Total_Pass_Yds_Gm_Al'] = float(Total_Pass_Yds_Gm_Al)
            
            Off_Plys_Al = stats[3][opp][10]
            df.loc[week, 'Off_Plys_Al'] = int(Off_Plys_Al) 
            
            Rush_Plys_Al = stats[2][opp][6]
            df.loc[week, 'Rush_Plys_Al'] = int(Rush_Plys_Al)

            Pass_Plys_Al = stats[2][opp][9].split('-')[0]
            df.loc[week, 'Pass_Plys_Al'] = int(Pass_Plys_Al)

            ## THROWING

            #weekly 
            Pass_Att = stats[a]['Att'].sum()
            df.loc[week, 'Pass_Att'] = float(Pass_Att)

            Completion_Rate = (stats[a]['Cmp'].sum())/(stats[a]['Att'].sum())
            df.loc[week, 'Completion_Rate'] = float(Completion_Rate)

            Pass_TDs = stats[a]['TD'].sum()
            df.loc[week, 'Pass_TDs'] = float(Pass_TDs)

            INTs = stats[a]['Int'].sum()
            df.loc[week, 'INTs'] = float(INTs)

            Sacks_Taken = stats[a]['Sack'].sum()
            df.loc[week, 'Sacks_Taken'] = float(Sacks_Taken)

            ##RUSHING 

            #weekly
            Rush_TDs = stats[c]['TD'].sum()
            df.loc[week,'Rush_TDs'] = float(Rush_TDs)

            Rush_Att = stats[c]['Att'].sum()
            df.loc[week, 'Rush_Att'] = float(Rush_Att)

            ##STATS BY DOWN
            #weekly
            Pass_1Ds_Gm = stats[2][team][2]
            df.loc[week, 'Pass_1Ds_Gm'] = float(Pass_1Ds_Gm)

            Rush_1Ds_Gm = stats[2][team][1]
            df.loc[week, 'Rush_1Ds_Gm'] = float(Rush_1Ds_Gm)

            First_Ds_Gm = stats[2][team][0]
            df.loc[week, 'First_Ds_Gm'] = float(First_Ds_Gm)

            if float(stats[3][team][8].split('-')[0]) == 0.0:
                Third_Conv_Perc = np.nan
            else:
                Third_Conv_Perc = float(stats[3][team][8].split('-')[2].replace('%',''))
            df.loc[week, 'Third_Conv_Perc'] = float(Third_Conv_Perc)

            if float(stats[3][team][9].split('-')[0]) == 0.0:
                Fourth_Conv_Perc = np.nan
            Fourth_Conv_Perc = float(stats[3][team][9].split('-')[2].replace('%',''))
            df.loc[week, 'Fourth_Conv_Perc'] = float(Fourth_Conv_Perc)


            ##DEFENSE 


            #weekly
            Sacks_Gm = stats[e]['Sack'].sum()
            df.loc[week, 'Sacks_Gm'] = float(Sacks_Gm)

            INT_Gm = stats[e]['Int'].sum()
            df.loc[week, 'INT_Gm'] = float(INT_Gm)

            Fumbles_Caused = stats[3][opp][6][2]
            df.loc[week, 'Fumbles_Caused'] = float(Fumbles_Caused)

            TO_Gm = float(stats[e]['Int'].sum()) + float(stats[3][opp][6][2])
            df.loc[week, 'TO_Gm'] = float(TO_Gm)

            ##SPECIAL TEAMS 

            ##Field Goals 

            #weekly
            if stats[g]['FG'].sum() == 0:
                FG_Att = 0
            else:
                FG_Att = float(stats[g]['FG'][0][2])
            df.loc[week, 'FG_Att'] = float(FG_Att)

            if FG_Att == 0:
                FG_Perc_Comp = np.nan
            else:
                FG_Perc_Comp = float(stats[g]['FG'][0][0])/FG_Att
            df.loc[week, 'FG_Perc_Comp'] = float(FG_Perc_Comp)

            ## PATs

            #weekly
            if stats[g]['PAT'].sum() == 0:
                PAT_Att = float(0)
            else:
                PAT_Att = float(stats[g]['PAT'][0][2])
            df.loc[week, 'PAT_Att'] = float(PAT_Att)

            if stats[g]['PAT'].sum() == 0:
                PAT_Perc_Comp = 0
            elif int(stats[g]['PAT'][0][2]) == 0:
                PAT_Perc_Comp = 0
            else:
                PAT_Perc_Comp = float(stats[g]['PAT'][0][0])/float(stats[g]['PAT'][0][2])
            df.loc[week, 'PAT_Perc_Comp'] = PAT_Perc_Comp

            ## Punts 

            #weekly
            if stats[i]['Punts'].sum() == 0:
                Punts = 0
            else:
                Punts = float(stats[i]['Punts'][0])
            df.loc[week, 'Punts'] = float(Punts)

            if stats[i]['Avg'].sum() == 0:
                Avg_Punt_Yds_Gm = np.nan
            else:
                Avg_Punt_Yds_Gm = float(stats[i]['Avg'][0])
            df.loc[week, 'Avg_Punt_Yds_Gm'] = float(Avg_Punt_Yds_Gm)

            if len(stats[k].index) == 0:
                Avg_Punt_Ret_Yds_Gm = 0
            else:    
                Avg_Punt_Ret_Yds_Gm = float(stats[k]['Avg'].sum()/len(stats[k].index))
            df.loc[week, 'Avg_Punt_Ret_Yds_Gm'] = float(Avg_Punt_Ret_Yds_Gm)

            if len(stats[k].index) == 0:
                Avg_Punt_Ret_Yds_Opp_Gm = 0
            else:
                Avg_Punt_Ret_Yds_Opp_Gm = float(stats[l]['Avg'].sum()/len(stats[k].index))
            df.loc[week, 'Avg_Punt_Ret_Yds_Opp_Gm'] = float(Avg_Punt_Ret_Yds_Opp_Gm)

            if stats[j]['RYds'].sum() == 0:
                Total_Punt_Ret_Yds_Gm = 0
            else:
                Total_Punt_Ret_Yds_Gm = float(stats[j]['RYds'][0])
            df.loc[week, 'Total_Punt_Ret_Yds_Gm'] = float(Total_Punt_Ret_Yds_Gm)

            if stats[i]['RYds'].sum() == 0:
                Total_Punt_Ret_Yds_Opp_Gm = 0
            else:
                Total_Punt_Ret_Yds_Opp_Gm = float(stats[i]['RYds'][0])
            df.loc[week, 'Total_Punt_Ret_Yds_Opp_Gm'] = float(Total_Punt_Ret_Yds_Opp_Gm)

            Punt_Ret_TD = float(stats[k]['TD'].sum())
            df.loc[week, 'Punt_Ret_TD'] = float(Punt_Ret_TD)

            Punt_Ret_TD_Opp = float(stats[l]['TD'].sum())
            df.loc[week, 'Punt_Ret_TD_Opp'] = float(Punt_Ret_TD_Opp)

            ## Kicking 

            #weekly
            if stats[m]['Num'].sum() == 0:
                Avg_Kick_Ret_Yds_Gm = 0
            else:
                Avg_Kick_Ret_Yds_Gm = (stats[m]['Yds'].sum()/stats[m]['Num'].sum())
            df.loc[week, 'Avg_Kick_Ret_Yds_Gm'] = float(Avg_Kick_Ret_Yds_Gm)

            if stats[n]['Num'].sum() == 0:
                Avg_Kick_Ret_Yds_Opp_Gm = 0
            else:
                Avg_Kick_Ret_Yds_Opp_Gm = float(stats[n]['Yds'].sum()/stats[n]['Num'].sum())
            df.loc[week, 'Avg_Kick_Ret_Yds_Opp_Gm'] = float(Avg_Kick_Ret_Yds_Opp_Gm)

            Kick_Ret_TD = float(stats[m]['TD'].sum())
            df.loc[week, 'Kick_Ret_TD'] = float(Kick_Ret_TD)

            Kick_Ret_TD_Opp = float(stats[n]['TD'].sum())
            df.loc[week, 'Kick_Ret_TD_Opp'] = float(Kick_Ret_TD_Opp)

            ##PENALTIES

            #weekly
            Penalties = stats[3][team][5] 
            df.loc[week, 'Penalties'] = Penalties

            Penalty_Gm = float(df.Penalties.map(lambda x: x.split('-')[0])[num])
            df.loc[week, 'Penalty_Gm'] = float(Penalty_Gm)

            Penalty_Yds_Gm = df.Penalties.map(lambda x: x.split('-')[1])[num]
            df.loc[week, 'Penalty_Yds_Gm'] = float(Penalty_Yds_Gm)

            ##TEAM

            #weekly
            df.loc[week, 'Playoff_app_5_yrs'] = NFL[team_name]['Playoff_app_5_yrs']

            df.loc[week, 'Superbowl_Win'] = NFL[team_name]['Superbowl_Win']

            df.loc[week, 'Draft_Pos'] = NFL[team_name]['Draft_Pos']

            df.loc[week, 'Week_Of_Szn'] = float(Week)

            df.loc[week, 'Perc_Pro_Bowl'] = NFL[team_name]['Perc_Pro_Bowl']
            
            df.loc[week, 'Year'] = 2018



            print(week)
            
    return df

# %% [markdown]
# 3. Use framework to pull and scrape datapoints

# %%
#create a dataframe
nfl_df = pd.DataFrame()

#list of team names
teams = ['Bears','Bengals','Bills','Broncos','Browns','Buccaneers','Colts','Cardinals','Chargers','Chiefs',
        'Cowboys','Dolphins','Eagles','Falcons','Giants','Jaguars','Jets','Lions','Packers','Panthers',
        'Patriots','Redskins','Raiders','Rams','Ravens','Saints','Seahawks','Steelers','Texans','Titans',
        'Vikings','49ers']

#for loop to concat all info into one df
for team in teams:
    nfl_df = pd.concat([nfl_df, Team_Stats(team)])
# Out:
# Week_1
# Week_2
# Week_3
# Week_4
# Week_6
# Week_7
# Week_8
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_18
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_10
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_10
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_6
# Week_7
# Week_8
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_18
# Week_19
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_18
# Week_19
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_10
# Week_11
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_18
# Week_19
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_18
# Week_19
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_10
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_18
# Week_19
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_10
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_7
# Week_8
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_8
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_10
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_18
# Week_19
# Week_20
# Week_1
# Week_2
# Week_3
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_8
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_10
# Week_11
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_18
# Week_19
# Week_20
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_18
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_7
# Week_8
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_18
# Week_19
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_8
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_18
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_8
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_18
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_9
# Week_10
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_11
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_10
# Week_12
# Week_13
# Week_14
# Week_15
# Week_16
# Week_17

# %% [markdown]
# 4. export to CSV

# %%
#exporting to csv
nfl_df.to_csv('/Users/carlyfaye/Documents/Flatiron/Football Project/nfl_stats_2018.csv', index = False)
