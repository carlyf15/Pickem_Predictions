# %% [markdown]
# ## 2020 Stats

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Create dictionary

# %%
NFL = {
    "Cardinals":{'team':'ArizonaAri', 'team_2':'Arizona Cardinals','team_3':'Arizona','bye':8,
                'Dates':['2020091312',
 '2020092011',
 '2020092709',
 '2020100401',
 '2020101106',
 '2020101901',
 '2020102509',
 '0'],
                'Superbowl_Win':0, 'Playoff_app_5_yrs':8, 'Draft_Pos':10, 'Perc_Pro_Bowl':1/53},
    
    "Falcons":{'team':'AtlantaAtl','team_2':'Atlanta Flacons','team_3':'Atlanta', 'bye':10,
               'Dates':['2020091301',
 '2020092002',
 '2020092701',
 '2020100501',
 '2020101101',
 '2020101804',
 '2020102501',
 '2020102901',
 '2020102901'],
               'Superbowl_Win':0, 'Playoff_app_5_yrs': 5, 'Draft_Pos':16, 'Perc_Pro_Bowl': 6/53},
    
    "Panthers":{'team':'CarolinaCar','team_2':'Carolina Panthers','team_3':'Carolina', 'bye':13,
             'Dates':['2020091304',
 '2020092009',
 '2020092711',
 '2020100401',
 '2020101101',
 '2020101801',
 '2020102506',
 '2020102901',
 '2020102901'],
    'Superbowl_Win':0, 'Playoff_app_5_yrs': 4, 'Draft_Pos':7, 'Perc_Pro_Bowl': 3/53},
    
    "Bears":{'team':'ChicagoChi','team_2':'Chicago Bears','team_3':'Chicago', 'bye':11,
            'Dates':['2020091305',
 '2020092001',
 '2020092701',
 '2020100402',
 '2020100801',
 '2020101801',
 '2020102601',
 '2020110109'],
            'Superbowl_Win': 0, 'Playoff_app_5_yrs':1, 'Draft_Pos':43, 'Perc_Pro_Bowl':8/53},
    
    "Cowboys":{'team':'DallasDal','team_2':'Dallas Cowboys','team_3':'Dallas', 'bye':10,
              'Dates':['2020091313',
 '2020092002',
 '2020092713',
 '2020100404',
 '2020101112',
 '2020101901',
 '2020102508',
 '2020110111'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':3, 'Draft_Pos':17, 'Perc_Pro_Bowl':8/53},
    
    "Lions":{'team':'DetroitDet','team_2':'Detroit Lions','team_3':'Detroit', 'bye':5,
              'Dates':['2020091305',
 '2020092003',
 '2020092709',
 '2020100405',
 '0',
 '2020101803',
 '2020102501',
 '2020110104'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':3, 'Draft_Pos':26, 'Perc_Pro_Bowl':2/53},
    
    "Packers":{'team':'Green BayGB', 'team_2':'Green Bay Packers', 'team_3':'Green Bay','bye': 5,
               'Dates':['2020091307',
 '2020092003',
 '2020092714',
 '2020100501',
 '0',
 '2020101811',
 '2020102504',
 '2020110105'], 
               'Superbowl_Win': 0, 'Playoff_app_5_yrs':7, 'Draft_Pos': 18, 'Perc_Pro_Bowl': 2/53},
    
    "Rams":{'team':'LA RamsLA','team_2':'LA Rams','team_3':'LA', 'bye':9,
              'Dates':['2020091313',
 '2020092007',
 '2020092702',
 '2020100411',
 '2020101109',
 '2020101812',
 '2020102601',
 '2020110107'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':4, 'Draft_Pos':52, 'Perc_Pro_Bowl':4/53},
    
    "Vikings":{'team':'MinnesotaMin','team_2':'Minnesota Vikings','team_3':'Minnesota', 'bye':7,
              'Dates':['2020091307',
 '2020092004',
 '2020092704',
 '2020100406',
 '2020101113',
 '2020101804',
 '0',
 '2020110105'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':3, 'Draft_Pos':22, 'Perc_Pro_Bowl':4/53},
    
    "Saints":{'team':'New OrleansNO','team_2':'New Orleans Saints','team_3':'New Orleans', 'bye':6,
              'Dates':['2020091311',
 '2020092101',
 '2020092714',
 '2020100405',
 '2020101201',
 '0',
 '2020102506',
 '2020091311'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':5, 'Draft_Pos':24, 'Perc_Pro_Bowl':8/53},
    
    "Giants":{'team':'NY GiantsNYG','team_2':'New York Giants','team_3':'New York', 'bye':11,
              'Dates':['2020091401',
 '2020092001',
 '2020092706',
 '2020100411',
 '2020101112',
 '2020101805',
 '2020102201',
 '2020110201'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':1, 'Draft_Pos':4, 'Perc_Pro_Bowl':5/53},
    
    "Eagles":{'team':'PhiladelphiaPhi','team_2':'Philadelphia Eagles','team_3':'Philadelphia', 'bye':9,
              'Dates':['2020091309',
 '2020092007',
 '2020092707',
 '2020100414',
 '2020101107',
 '2020101806',
 '2020102201',
 '2020110111'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':6, 'Draft_Pos':21, 'Perc_Pro_Bowl':5/53},
    
    "49ers":{'team':'San FranciscoSF','team_2':'San Francisco 49ers', 'team_3':'San Francisco', 'bye':11, 
            'Dates':['2020091312',
 '2020092006',
 '2020092706',
 '2020100414',
 '2020101110',
 '2020101812',
 '2020102511',
 '2020110110'], 'Superbowl_Win': 0, 'Playoff_app_5_yrs': 3, 'Draft_Pos': 14, 'Perc_Pro_Bowl': 3/53},
    
    "Seahawks":{'team':'SeattleSea','team_2':'Seattle Seahawks','team_3':'Seattle', 'bye':6,
              'Dates':['2020091301',
 '2020092014',
 '2020092713',
 '2020100407',
 '2020101113',
 '0',
 '2020102509',
 '2020110110'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':7, 'Draft_Pos':27, 'Perc_Pro_Bowl':3/53},
    
    "Buccaneers":{'team':'Tampa BayTB','team_2':'Tampa Bay Buccaneers','team_3':'Tampa Bay', 'bye':13,
              'Dates':['2020091311',
 '2020092009',
 '2020092712',
 '2020100408',
 '2020100801',
 '2020101811',
 '2020102512',
 '2020110201'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':0, 'Draft_Pos':13, 'Perc_Pro_Bowl':1/53},
    
    "Redskins":{'team':'WashingtonWas', 'team_2':'Washington Redskins','team_3':'Washington','bye':8, 
                'Dates':['2020091309',
 '2020092011',
 '2020092703',
 '2020100410',
 '2020101109',
 '2020101805',
 '2020102508',
 '0'], 
                'Superbowl_Win': 0, 'Playoff_app_5_yrs': 1, 'Draft_Pos': 2, 'Perc_Pro_Bowl': 2/53 },
    
    "Ravens":{'team':'BaltimoreBal', 'team_2':'Baltimore Ravens', 'team_3': 'Baltimore', 'bye': 7, 
             'Dates':['2020091302',
 '2020092012',
 '2020092801',
 '2020100410',
 '2020101102',
 '2020101806',
 '0',
 '2020101102'], 
              'Superbowl_Win': 0, 'Playoff_app_5_yrs':2, 'Draft_Pos':25,'Perc_Pro_Bowl': 4/53},
    
    "Bills":{'team':'BuffaloBuf','team_2':'Buffalo Bills','team_3':'Buffalo', 'bye':11,
            'Dates':['2020091303',
 '2020092005',
 '2020092702',
 '2020100413',
 '2020101108',
 '2020101501',
 '2020102507',
 '2020110101'], 
             'Superbowl_Win': 0, 'Playoff_app_5_yrs':2, 'Draft_Pos':54, 'Perc_Pro_Bowl': 1/53},
    
     "Bengals":{'team':'CincinnatiCin','team_2':'Cincinnati Bengals','team_3':'Cincinnati', 'bye':9,
              'Dates':['2020091310',
 '2020091701',
 '2020092707',
 '2020100403',
 '2020101102',
 '2020101802',
 '2020102503',
 '2020110102'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':1, 'Draft_Pos':1, 'Perc_Pro_Bowl':1/53},
    
    "Browns":{'team':'ClevelandCle','team_2':'Cleveland Browns','team_3':'Cleveland', 'bye':9,
              'Dates':['2020091302',
 '2020091701',
 '2020092703',
 '2020100404',
 '2020101111',
 '2020101807',
 '2020102503',
 '2020110103'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':0, 'Draft_Pos':10, 'Perc_Pro_Bowl':4/53},
    
    "Broncos":{'team':'DenverDen','team_2':'Denver Broncos','team_3':'Denver', 'bye':5,
              'Dates':['2020091402',
 '2020092008',
 '2020092712',
 '2020100101',
 '0',
 '2020101105',
 '2020102510',
 '2020112209'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':3, 'Draft_Pos':15, 'Perc_Pro_Bowl':4/53},
    
    "Texans":{'team':'HoustonHou','team_2':'Houston Texans','team_3':'Houston', 'bye':8,
              'Dates':['2020091001',
 '2020092012',
 '2020092708',
 '2020100406',
 '2020101103',
 '2020101808',
 '2020102504',
 '0'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':6, 'Draft_Pos':40, 'Perc_Pro_Bowl':6/53},
    
    "Colts":{'team':'IndianapolisInd','team_2':'Indianapolis Colts','team_3':'Indianapolis', 'bye':7,
              'Dates':['2020091306',
 '2020092004',
 '2020092710',
 '2020100402',
 '2020101111',
 '2020101802',
 '0',
  '2020110104'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':2, 'Draft_Pos':34, 'Perc_Pro_Bowl':3/53},
    
    "Jaguars":{'team':'JacksonvilleJax','team_2':'Jacksonville Jaguars','team_3':'Jacksonville', 'bye':8,
              'Dates':['2020091306',
 '2020092010',
 '2020092401',
 '2020100403',
 '2020101103',
 '2020101803',
 '2020110108',
 '0'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':3, 'Draft_Pos':9, 'Perc_Pro_Bowl':2/53},
    
    "Chiefs":{'team':'Kansas CityKC','team_2':'Kansas City Chiefs','team_3':'Kansas City', 'bye':10,
              'Dates':['2020091001',
 '2020092013',
 '2020092801',
 '2020100412',
 '2020101104',
 '2020101501',
 '2020102510',
 '2020110106'],
              'Superbowl_Win':1, 'Playoff_app_5_yrs':9, 'Draft_Pos':32, 'Perc_Pro_Bowl':6/53},
    
    "Raiders":{'team':'Las VegasLV','team_2':'Las Vegas Raiders','team_3':'Las Vegas', 'bye':6,
              'Dates':['2020091304',
 '2020092101',
 '2020092705',
 '2020100413',
 '2020101104',
 '0',
 '2020102512',
 '2020110103'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':1, 'Draft_Pos':12, 'Perc_Pro_Bowl':1/53},
    
    "Chargers":{'team':'LA ChargersLAC','team_2':'Los Angeles Chargers','team_3':'Los Angeles', 'bye':6,
              'Dates':['2020091310',
 '2020092013',
 '2020092711',
 '2020100408',
 '2020101201',
 '0',
 '2020110108',
 '2020112209'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':2, 'Draft_Pos':6, 'Perc_Pro_Bowl':7/53},
    
    "Dolphins":{'team':'MiamiMia','team_2':'Miami Dolphins','team_3':'Miami', 'bye':7,
               'Dates':['2020091308',
 '2020092005',
 '2020092401',
 '2020100407',
 '2020101110',
 '2020111509',
 '0',
 '2020110107'],
               'Superbowl_Win':0, 'Playoff_app_5_yrs': 1, 'Draft_Pos':5, 'Perc_Pro_Bowl': 1/53},
    
    "Patriots":{'team':'New EnglandNE','team_2':'New England Patriots','team_3':'New England', 'bye':5,
               'Dates':['2020091308',
 '2020092014',
 '2020092705',
 '2020100412',
 '0',
 '2020101105',
 '2020102511',
 '2020110101'],
               'Superbowl_Win':0, 'Playoff_app_5_yrs': 12, 'Draft_Pos':37, 'Perc_Pro_Bowl': 2/53},
    
    "Jets":{'team':'NY JetsNYJ','team_2':'New York Jets','team_3':'New York', 'bye':11,
              'Dates':['2020091303',
 '2020092006',
 '2020092710',
 '2020100101',
 '2020101106',
 '2020111509',
 '2020102507',
 '2020110106'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':0, 'Draft_Pos':11, 'Perc_Pro_Bowl':3/53},
    
    "Steelers":{'team':'PittsburghPit','team_2':'Pitsburgh Steelers','team_3':'Pittsburgh', 'bye':4,
              'Dates':['2020091401',
 '2020092008',
 '2020092708',
 '0',
 '2020101107',
 '2020101807',
 '2020100409',
 '2020102502'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':6, 'Draft_Pos':49, 'Perc_Pro_Bowl':8/53},
    
    "Titans":{'team':'TennesseeTen','team_2':'Tennessee Titans','team_3':'Tennessee', 'bye':4,
              'Dates':['2020091402',
 '2020092010',
 '2020092704',
 '0',
 '2020101108',
 '2020101808',
 '2020100409',
 '2020110102'],
              'Superbowl_Win':0, 'Playoff_app_5_yrs':5, 'Draft_Pos':29, 'Perc_Pro_Bowl':3/53},

}

# %% [markdown]
# ### Create DF

# %%
def Team_Stats(team_name):
    
    '''input: team name 
       output: dataframe w/ weekly statistics from all 32 NFL teams'''

    #create df w/ all columns
    df = pd.DataFrame(columns=[       'Team_Name',
                                      'Pts_Scored',
                                      'Pts_Al',
                                      'Win',
                                      'TDs',
                                      'First_Sc',
                                      'Second_Sc',
                                      'Third_Sc',
                                      'Fourth_Sc',
                                      'First_Al',
                                      'Second_Al',
                                      'Third_Al',
                                      'Fourth_Al',

                                      'Off_Plys',
                                      'Rush_Plys',
                                      'Pass_Plys',
                                      'Fumbles',

                                      'Yds_Ply',
                                      'Yds_Rush',
                                      'Yds_Pass',
                                      'Total_Yds_Gm',
                                      'Total_Rush_Yds_Gm',
                                      'Total_Pass_Yds_Gm',
                                    
                                      'Yds_Ply_Al',
                                      'Yds_Rush_Al',
                                      'Yds_Pass_Al',
                                      'Total_Yds_Gm_Al',
                                      'Total_Rush_Yds_Gm_Al',
                                      'Total_Pass_Yds_Gm_Al',
                                      'Off_Plys_Al',
                                      'Rush_Plys_Al',
                                      'Pass_Plys_Al',
                                    
                                      'Completion_Rate',
                                      'Pass_Att',
                                      'Pass_TDs',
                                      'INTs',
                                      'Sacks_Taken',
                                    
                                      'Rush_TDs',
                                      'Rush_Att',
                                      
                                      'Pass_1Ds_Gm',
                                      'Rush_1Ds_Gm',
                                      'First_Ds_Gm',
                                      'Third_Conv_Perc',
                                      'Fourth_Conv_Perc',
                                      
                                      'Sacks_Gm',
                                      'INT_Gm',
                                      'Fumbles_Caused',
                                      'TO_Gm',

                                      'FG_Att',
                                      'FG_Perc_Comp',

                                      'PAT_Att',
                                      'PAT_Perc_Comp',

                                      'Punts',
                                      'Avg_Punt_Yds_Gm',
                                      'Avg_Punt_Ret_Yds_Gm',
                                      'Avg_Punt_Ret_Yds_Opp_Gm',
                                      'Total_Punt_Ret_Yds_Gm',
                                      'Total_Punt_Ret_Yds_Opp_Gm',
                                      'Punt_Ret_TD',
                                      'Punt_Ret_TD_Opp',
                                    
                                      'Avg_Kick_Ret_Yds_Gm',
                                      'Avg_Kick_Ret_Yds_Opp_Gm',
                                      'Kick_Ret_TD_Opp',
                                      'Kick_Ret_TD',

                                      'Penalties',
                                      'Penalty_Gm',
                                      'Penalty_Yds_Gm',

                                      'Playoff_app_5_yrs',
                                      'Superbowl_Win',
                                      'Draft_Pos',
                                      'Week_Of_Szn',
                                     'Perc_Pro_Bowl'])

    #for loop which will loop thru each week in list of dates for a single nfl team
    for week,date in enumerate(NFL[team_name]['Dates']):
        Week = int(week) + 1
        if date == '0':
            df.fillna('bye')
        else:
            bye = NFL[team_name]['bye']
            if week < bye:
                num = week
            else: 
                num = week - 1
            team = NFL[team_name]['team']
            team_2 = NFL[team_name]['team_2']
            team_3 = NFL[team_name]['team_3']
            week = ('Week_' + str(Week))
            #looping thru dates 
            stats = pd.read_html('https://www.footballdb.com/games/boxscore.html?gid=' + date)
            #the website has different order based on home/away, fixed below
            if stats[3].columns[2] == team:
                #home
                x = 2 
                y = 1
                a = 5
                b = 4
                c = 7
                d = 6
                e = 21
                f = 20
                g = 17
                h = 16
                i = 15
                j = 14
                k = 13
                l = 12
                m = 11
                n = 10
                o = 8
            else:
                #away
                a = 4
                b = 5
                c = 6
                d = 7
                x = 1
                y = 2
                e = 20
                f = 21
                g = 16
                h = 17
                i = 14
                j = 15
                k = 12
                l = 13
                m = 10
                n = 11
                o = 9
            
            opp = stats[3].columns[y]
            
            df.loc[week, 'Team_Name'] = team_name
            
            df.loc[week, 'Opp_Name'] = stats[o].columns[0].split()[-1]

            ##SCORING
            # Weekly
            if len(stats[0].columns) == 7:
                Pts_Scored = stats[0][6][x]
            else: 
                Pts_Scored = stats[0][5][x]
            df.loc[week, 'Pts_Scored'] = int(Pts_Scored)

            if len(stats[0].columns) == 7:
                Pts_Al = stats[0][6][y]
            else:
                Pts_Al = stats[0][5][y]
            df.loc[week, 'Pts_Al'] = int(Pts_Al)

            if df.Pts_Al[num] < df.Pts_Scored[num]:
                Win = 1
            else:
                Win = 0
            df.loc[week, 'Win'] = float(Win)

            TDs = stats[a]['TD'].sum() + stats[c]['TD'].sum()
            df.loc[week, 'TDs'] = float(TDs)

            First_Sc = stats[0][1][x]
            df.loc[week, 'First_Sc' ] = float(First_Sc)

            Second_Sc = stats[0][2][x]
            df.loc[week, 'Second_Sc' ] = float(Second_Sc)

            Third_Sc = stats[0][3][x]
            df.loc[week, 'Third_Sc'] = float(Third_Sc)

            Fourth_Sc = stats[0][4][x]
            df.loc[week, 'Fourth_Sc'] = float(Fourth_Sc)

            First_Al = stats[0][1][y]
            df.loc[week, 'First_Al'] = float(First_Al)

            Second_Al = stats[0][2][y]
            df.loc[week, 'Second_Al'] = float(Second_Al)

            Third_Al = stats[0][3][y]
            df.loc[week, 'Third_Al'] = float(Third_Al)

            Fourth_Al = stats[0][4][y]
            df.loc[week, 'Fourth_Al'] = float(Fourth_Al)

            ##OFFENSE 
            #weekly 
            Off_Plys = stats[3][team][10]
            df.loc[week, 'Off_Plys'] = int(Off_Plys)

            Rush_Plys = stats[2][team][6]
            df.loc[week, 'Rush_Plys'] = int(Rush_Plys)

            Pass_Plys = stats[2][team][9].split('-')[0]
            df.loc[week, 'Pass_Plys'] = int(Pass_Plys)

            Fumbles = stats[3][team][6][2]
            df.loc[week, 'Fumbles'] = float(Fumbles)

            ## OFFENSIVE YARDAGE 
            #weekly
            Yds_Ply = stats[3][team][11]
            df.loc[week, 'Yds_Ply'] = float(Yds_Ply)

            Yds_Rush = stats[2][team][7]
            df.loc[week, 'Yds_Rush'] = float(Yds_Rush)

            Yds_Pass = stats[2][team][12]
            df.loc[week, 'Yds_Pass'] = float(Yds_Pass)

            Total_Yds_Gm = stats[2][team][4]
            df.loc[week, 'Total_Yds_Gm'] = float(Total_Yds_Gm)

            Total_Rush_Yds_Gm = stats[2][team][5]
            df.loc[week, 'Total_Rush_Yds_Gm'] = float(Total_Rush_Yds_Gm)

            Total_Pass_Yds_Gm = stats[2][team][8]
            df.loc[week, 'Total_Pass_Yds_Gm'] = float(Total_Pass_Yds_Gm)
            
            ## YARDS ALLOWED 
             #weekly
            Yds_Ply_Al = stats[3][opp][11]
            df.loc[week, 'Yds_Ply_Al'] = float(Yds_Ply)

            Yds_Rush_Al = stats[2][opp][7]
            df.loc[week, 'Yds_Rush_Al'] = float(Yds_Rush_Al)

            Yds_Pass_Al = stats[2][opp][12]
            df.loc[week, 'Yds_Pass_Al'] = float(Yds_Pass_Al)

            Total_Yds_Gm_Al = stats[2][opp][4]
            df.loc[week, 'Total_Yds_Gm_Al'] = float(Total_Yds_Gm_Al)

            Total_Rush_Yds_Gm_Al = stats[2][opp][5]
            df.loc[week, 'Total_Rush_Yds_Gm_Al'] = float(Total_Rush_Yds_Gm_Al)

            Total_Pass_Yds_Gm_Al = stats[2][opp][8]
            df.loc[week, 'Total_Pass_Yds_Gm_Al'] = float(Total_Pass_Yds_Gm_Al)
            
            Off_Plys_Al = stats[3][opp][10]
            df.loc[week, 'Off_Plys_Al'] = int(Off_Plys_Al) 
            
            Rush_Plys_Al = stats[2][opp][6]
            df.loc[week, 'Rush_Plys_Al'] = int(Rush_Plys_Al)

            Pass_Plys_Al = stats[2][opp][9].split('-')[0]
            df.loc[week, 'Pass_Plys_Al'] = int(Pass_Plys_Al)

            ## THROWING

            #weekly 
            Pass_Att = stats[a]['Att'].sum()
            df.loc[week, 'Pass_Att'] = float(Pass_Att)

            Completion_Rate = (stats[a]['Cmp'].sum())/(stats[a]['Att'].sum())
            df.loc[week, 'Completion_Rate'] = float(Completion_Rate)

            Pass_TDs = stats[a]['TD'].sum()
            df.loc[week, 'Pass_TDs'] = float(Pass_TDs)

            INTs = stats[a]['Int'].sum()
            df.loc[week, 'INTs'] = float(INTs)

            Sacks_Taken = stats[a]['Sack'].sum()
            df.loc[week, 'Sacks_Taken'] = float(Sacks_Taken)

            ##RUSHING 

            #weekly
            Rush_TDs = stats[c]['TD'].sum()
            df.loc[week,'Rush_TDs'] = float(Rush_TDs)

            Rush_Att = stats[c]['Att'].sum()
            df.loc[week, 'Rush_Att'] = float(Rush_Att)

            ##STATS BY DOWN
            #weekly
            Pass_1Ds_Gm = stats[2][team][2]
            df.loc[week, 'Pass_1Ds_Gm'] = float(Pass_1Ds_Gm)

            Rush_1Ds_Gm = stats[2][team][1]
            df.loc[week, 'Rush_1Ds_Gm'] = float(Rush_1Ds_Gm)

            First_Ds_Gm = stats[2][team][0]
            df.loc[week, 'First_Ds_Gm'] = float(First_Ds_Gm)

            if float(stats[3][team][8].split('-')[0]) == 0.0:
                Third_Conv_Perc = np.nan
            else:
                Third_Conv_Perc = float(stats[3][team][8].split('-')[2].replace('%',''))
            df.loc[week, 'Third_Conv_Perc'] = float(Third_Conv_Perc)

            if float(stats[3][team][9].split('-')[0]) == 0.0:
                Fourth_Conv_Perc = np.nan
            Fourth_Conv_Perc = float(stats[3][team][9].split('-')[2].replace('%',''))
            df.loc[week, 'Fourth_Conv_Perc'] = float(Fourth_Conv_Perc)


            ##DEFENSE 


            #weekly
            Sacks_Gm = stats[e]['Sack'].sum()
            df.loc[week, 'Sacks_Gm'] = float(Sacks_Gm)

            INT_Gm = stats[e]['Int'].sum()
            df.loc[week, 'INT_Gm'] = float(INT_Gm)

            Fumbles_Caused = stats[3][opp][6][2]
            df.loc[week, 'Fumbles_Caused'] = float(Fumbles_Caused)

            TO_Gm = float(stats[e]['Int'].sum()) + float(stats[3][opp][6][2])
            df.loc[week, 'TO_Gm'] = float(TO_Gm)

            ##SPECIAL TEAMS 

            ##Field Goals 

            #weekly
            if stats[g]['FG'].sum() == 0:
                FG_Att = 0
            else:
                FG_Att = float(stats[g]['FG'][0][2])
            df.loc[week, 'FG_Att'] = float(FG_Att)

            if FG_Att == 0:
                FG_Perc_Comp = np.nan
            else:
                FG_Perc_Comp = float(stats[g]['FG'][0][0])/FG_Att
            df.loc[week, 'FG_Perc_Comp'] = float(FG_Perc_Comp)

            ## PATs

            #weekly
            if stats[g]['PAT'].sum() == 0:
                PAT_Att = float(0)
            else:
                PAT_Att = float(stats[g]['PAT'][0][2])
            df.loc[week, 'PAT_Att'] = float(PAT_Att)

            if stats[g]['PAT'].sum() == 0:
                PAT_Perc_Comp = 0
            elif int(stats[g]['PAT'][0][2]) == 0:
                PAT_Perc_Comp = 0
            else:
                PAT_Perc_Comp = float(stats[g]['PAT'][0][0])/float(stats[g]['PAT'][0][2])
            df.loc[week, 'PAT_Perc_Comp'] = PAT_Perc_Comp

            ## Punts 

            #weekly
            if stats[i]['Punts'].sum() == 0:
                Punts = 0
            else:
                Punts = float(stats[i]['Punts'][0])
            df.loc[week, 'Punts'] = float(Punts)

            if stats[i]['Avg'].sum() == 0:
                Avg_Punt_Yds_Gm = np.nan
            else:
                Avg_Punt_Yds_Gm = float(stats[i]['Avg'][0])
            df.loc[week, 'Avg_Punt_Yds_Gm'] = float(Avg_Punt_Yds_Gm)

            if len(stats[k].index) == 0:
                Avg_Punt_Ret_Yds_Gm = 0
            else:    
                Avg_Punt_Ret_Yds_Gm = float(stats[k]['Avg'].sum()/len(stats[k].index))
            df.loc[week, 'Avg_Punt_Ret_Yds_Gm'] = float(Avg_Punt_Ret_Yds_Gm)

            if len(stats[k].index) == 0:
                Avg_Punt_Ret_Yds_Opp_Gm = 0
            else:
                Avg_Punt_Ret_Yds_Opp_Gm = float(stats[l]['Avg'].sum()/len(stats[k].index))
            df.loc[week, 'Avg_Punt_Ret_Yds_Opp_Gm'] = float(Avg_Punt_Ret_Yds_Opp_Gm)

            if stats[j]['RYds'].sum() == 0:
                Total_Punt_Ret_Yds_Gm = 0
            else:
                Total_Punt_Ret_Yds_Gm = float(stats[j]['RYds'][0])
            df.loc[week, 'Total_Punt_Ret_Yds_Gm'] = float(Total_Punt_Ret_Yds_Gm)

            if stats[i]['RYds'].sum() == 0:
                Total_Punt_Ret_Yds_Opp_Gm = 0
            else:
                Total_Punt_Ret_Yds_Opp_Gm = float(stats[i]['RYds'][0])
            df.loc[week, 'Total_Punt_Ret_Yds_Opp_Gm'] = float(Total_Punt_Ret_Yds_Opp_Gm)

            Punt_Ret_TD = float(stats[k]['TD'].sum())
            df.loc[week, 'Punt_Ret_TD'] = float(Punt_Ret_TD)

            Punt_Ret_TD_Opp = float(stats[l]['TD'].sum())
            df.loc[week, 'Punt_Ret_TD_Opp'] = float(Punt_Ret_TD_Opp)

            ## Kicking 

            #weekly
            if stats[m]['Num'].sum() == 0:
                Avg_Kick_Ret_Yds_Gm = 0
            else:
                Avg_Kick_Ret_Yds_Gm = (stats[m]['Yds'].sum()/stats[m]['Num'].sum())
            df.loc[week, 'Avg_Kick_Ret_Yds_Gm'] = float(Avg_Kick_Ret_Yds_Gm)

            if stats[n]['Num'].sum() == 0:
                Avg_Kick_Ret_Yds_Opp_Gm = 0
            else:
                Avg_Kick_Ret_Yds_Opp_Gm = float(stats[n]['Yds'].sum()/stats[n]['Num'].sum())
            df.loc[week, 'Avg_Kick_Ret_Yds_Opp_Gm'] = float(Avg_Kick_Ret_Yds_Opp_Gm)

            Kick_Ret_TD = float(stats[m]['TD'].sum())
            df.loc[week, 'Kick_Ret_TD'] = float(Kick_Ret_TD)

            Kick_Ret_TD_Opp = float(stats[n]['TD'].sum())
            df.loc[week, 'Kick_Ret_TD_Opp'] = float(Kick_Ret_TD_Opp)

            ##PENALTIES

            #weekly
            Penalties = stats[3][team][5] 
            df.loc[week, 'Penalties'] = Penalties

            Penalty_Gm = float(df.Penalties.map(lambda x: x.split('-')[0])[num])
            df.loc[week, 'Penalty_Gm'] = float(Penalty_Gm)

            Penalty_Yds_Gm = df.Penalties.map(lambda x: x.split('-')[1])[num]
            df.loc[week, 'Penalty_Yds_Gm'] = float(Penalty_Yds_Gm)

            ##TEAM

            #weekly
            df.loc[week, 'Playoff_app_5_yrs'] = NFL[team_name]['Playoff_app_5_yrs']

            df.loc[week, 'Superbowl_Win'] = NFL[team_name]['Superbowl_Win']

            df.loc[week, 'Draft_Pos'] = NFL[team_name]['Draft_Pos']

            df.loc[week, 'Week_Of_Szn'] = float(Week)

            df.loc[week, 'Perc_Pro_Bowl'] = NFL[team_name]['Perc_Pro_Bowl']
            
            df.loc[week, 'Year'] = 2020



            print(week)
            
    return df

# %% [markdown]
# ### Adding stats to DF

# %%
#create a dataframe
nfl_df = pd.DataFrame()

#list of team names
teams = ['Bears','Bengals','Bills','Broncos','Browns','Buccaneers','Colts','Cardinals','Chargers','Chiefs',
        'Cowboys','Dolphins','Eagles','Falcons','Giants','Jaguars','Jets','Lions','Packers','Panthers',
        'Patriots','Redskins','Raiders','Rams','Ravens','Saints','Seahawks','Steelers','Texans','Titans',
        'Vikings','49ers']

#for loop to concat all info into one df
for team in teams:
    nfl_df = pd.concat([nfl_df, Team_Stats(team)])
# Out:
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_9
# Week_1
# Week_2
# Week_3
# Week_4
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_5
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_1
# Week_2
# Week_3
# Week_5
# Week_6
# Week_7
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_8
# Week_1
# Week_2
# Week_3
# Week_4
# Week_5
# Week_6
# Week_7
# Week_8

# %% [markdown]
# ### Export to CSV

# %%
#exporting to csv
nfl_df.to_csv('/Users/carlyfaye/Documents/Flatiron/Pickem_Predictions/CSV_Files/nfl_stats_2020.csv', index=False)

# %%
nfl_df
# Out:
#        Team_Name  Pts_Scored  Pts_Al  Win  TDs  First_Sc  Second_Sc  Third_Sc  \
# Week_1     Bears        27.0    23.0  1.0  3.0       3.0        3.0       0.0
# Week_2     Bears        17.0    13.0  1.0  2.0      10.0        7.0       0.0
# Week_3     Bears        30.0    26.0  1.0  4.0       3.0        7.0       0.0
# Week_4     Bears        11.0    19.0  0.0  1.0       0.0        3.0       0.0
# Week_5     Bears        20.0    19.0  1.0  2.0       0.0       14.0       0.0
# ...          ...         ...     ...  ...  ...       ...        ...       ...
# Week_4     49ers        20.0    25.0  0.0  3.0       7.0        0.0       7.0
# Week_5     49ers        17.0    43.0  0.0  2.0       0.0        7.0      10.0
# Week_6     49ers        24.0    16.0  1.0  3.0       7.0       14.0       0.0
# Week_7     49ers        33.0     6.0  1.0  4.0       7.0       16.0       7.0
# Week_8     49ers        27.0    37.0  0.0  4.0       0.0        7.0       0.0
#
#         Fourth_Sc  First_Al  ...  Penalties  Penalty_Gm  Penalty_Yds_Gm  \
# Week_1       21.0       3.0  ...       6-48         6.0            48.0
# Week_2        0.0       0.0  ...       5-48         5.0            48.0
# Week_3       20.0       6.0  ...      10-80        10.0            80.0
# Week_4        8.0       7.0  ...      8-103         8.0           103.0
# Week_5        6.0      10.0  ...       6-66         6.0            66.0
# ...           ...       ...  ...        ...         ...             ...
# Week_4        6.0       8.0  ...       6-42         6.0            42.0
# Week_5        0.0      14.0  ...       7-75         7.0            75.0
# Week_6        3.0       0.0  ...       7-63         7.0            63.0
# Week_7        3.0       0.0  ...       6-65         6.0            65.0
# Week_8       20.0       6.0  ...       6-36         6.0            36.0
#
#         Playoff_app_5_yrs  Superbowl_Win  Draft_Pos  Week_Of_Szn  \
# Week_1                1.0            0.0       43.0          1.0
# Week_2                1.0            0.0       43.0          2.0
# Week_3                1.0            0.0       43.0          3.0
# Week_4                1.0            0.0       43.0          4.0
# Week_5                1.0            0.0       43.0          5.0
# ...                   ...            ...        ...          ...
# Week_4                3.0            0.0       14.0          4.0
# Week_5                3.0            0.0       14.0          5.0
# Week_6                3.0            0.0       14.0          6.0
# Week_7                3.0            0.0       14.0          7.0
# Week_8                3.0            0.0       14.0          8.0
#
#        Perc_Pro_Bowl            Opp_Name    Year
# Week_1      0.150943        LionsDetroit  2020.0
# Week_2      0.150943              Giants  2020.0
# Week_3      0.150943      FalconsAtlanta  2020.0
# Week_4      0.150943   ColtsIndianapolis  2020.0
# Week_5      0.150943                 Bay  2020.0
# ...              ...                 ...     ...
# Week_4     0.0566038  EaglesPhiladelphia  2020.0
# Week_5     0.0566038       DolphinsMiami  2020.0
# Week_6     0.0566038                Rams  2020.0
# Week_7     0.0566038             England  2020.0
# Week_8     0.0566038     SeahawksSeattle  2020.0
#
# [240 rows x 74 columns]
